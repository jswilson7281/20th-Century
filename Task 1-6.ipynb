kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 758.9 kB/s eta 0:00:01
#      -------------------------------------- 12.8/12.8 MB 760.9 kB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# [!] As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use
# the full pipeline package name 'en_core_web_sm' instead.
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English module

NER = spacy.load("en_core_web_sm")

# %%
# Load the book

with open('20th_Century.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')

book = NER(data)

# %%
# Visualize identified entities

displacy.render(book[273:500], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">          2 See also         3 References         4 Sources         5 External links                   Toggle the table of contents        Key events of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  languages     Ø§Ù„Ø¹Ø±Ø¨ÙŠØ©Ð£ÐºÑ€Ð°Ñ—
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ð½ÑÑŒÐºÐ°  Edit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  links            ArticleTalk
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
#                   ReadEditView history
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tools      Tools
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  move to sidebar hide    		Actions 	   ReadEditView history      		General 	   What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageGet shortened
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     URLDownload
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  QR code      		Print/export
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Download
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PDFPrintable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  version      		In other projects
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikimedia CommonsWikidata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  item                      Appearance move to sidebar hide           From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the free encyclopedia
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  changed the world in unprecedented ways.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The World Wars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sparked tension between countries and led to the creation of atomic bombs,
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Cold War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  led to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Space Race
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and the creation of space-based rockets, and
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the World Wide Web
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  was created. These advancements have played a significant role in citizens' lives and shaped
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 21st century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into what it is
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Historic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  events in the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  century[edit] World at the beginning of the century[edit] Main article: Edwardian era The new beginning of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  marked significant changes.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The 1900s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  saw
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  herald a series of inventions, including </div></span>

# %%
df_sentences = []

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})

df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (    , Key, events, of, the, 20th, century, -,...
# 1  (articleAbout, WikipediaContact, us,      \t\t...
# 2  (1.1.2, Russian, Revolution, and, communism,  ...
# 3  (1.3.1, The, war, in, Europe,         , 1.3.2,...
# 4  (Operation, Overlord,         , 1.3.6, Final, ...
# 5  (Allied, offensive,         , 1.3.10, Final, d...
# 6       (The, Nuclear, Age, begins,           , 1.4)
# 7          (The, post, -, war, world,       , 1.4.1)
# 8  (The, end, of, empires, :, decolonization,    ...
# 9  (The, space, race,         , 1.4.5, The, end, ...
#
#                                             entities
# 0                               [the 20th century -]
# 1  [Search            Search                     ...
# 2  [1.2, 1.2.1 Economic depression         , 1.3,...
# 3   [1.3.1, Europe, 1.3.2, Blitzkrieg         1.3.3]
# 4  [the Pacific       , 1.3.7.1, 1.3.8, Japanese,...
# 5                                                 []
# 6                             [The Nuclear Age, 1.4]
# 7                                            [1.4.1]
# 8                 [1.4.2, The Cold War, 1947â€“1991]
# 9  [the Cold War         1.4.6 Information, 1.5, ...

# %%
countries_df = pd.read_csv("countries_list_20th_century_1.5.csv",index_col=0)

# %%
countries_df["country_name"]=countries_df["country_name"].str.strip()

# %%
# Function to filter out entities not of interest

def filter_entity(ent_list, countries_df):
    return [ent for ent in ent_list
                  if ent in list(countries_df['country_name'])]

# %%
df_sentences['country_name'] = df_sentences['entities'].apply(lambda x: filter_entity(x, countries_df))

# %%
df_sentences
# Out:
#                                                sentence  \
# 0     (    , Key, events, of, the, 20th, century, -,...
# 1     (articleAbout, WikipediaContact, us,      \t\t...
# 2     (1.1.2, Russian, Revolution, and, communism,  ...
# 3     (1.3.1, The, war, in, Europe,         , 1.3.2,...
# 4     (Operation, Overlord,         , 1.3.6, Final, ...
# ...                                                 ...
# 1593  (Art, Christianity, Literature, Music, classic...
# 1594  (Text, is, available, under, the, Creative, Co...
# 1595  (By, using, this, site, ,, you, agree, to, the...
# 1596  (WikipediaÂ, ®, is, a, registered, trademark, ...
# 1597  (Privacy, policy, About, Wikipedia, Disclaimer...
#
#                                                entities country_name
# 0                                  [the 20th century -]           []
# 1     [Search            Search                     ...           []
# 2     [1.2, 1.2.1 Economic depression         , 1.3,...           []
# 3      [1.3.1, Europe, 1.3.2, Blitzkrieg         1.3.3]           []
# 4     [the Pacific       , 1.3.7.1, 1.3.8, Japanese,...           []
# ...                                                 ...          ...
# 1593  [Art Christianity Literature Music, 1970s 1980...           []
# 1594  [the Creative Commons Attribution-ShareAlike 4...           []
# 1595              [the Terms of Use and Privacy Policy]           []
# 1596      [WikipediaÂ®, the Wikimedia Foundation, Inc.]           []
# 1597                                           [Mobile]           []
#
# [1598 rows x 3 columns]

# %%
# Filter out sentences 

df_sentences_filtered = df_sentences[df_sentences['country_name'].map(len) > 0]

df_sentences_filtered.tail(10)
# Out:
#                                                sentence  \
# 1088  (", The, forgotten, violence, that, helped, In...
# 1093  (", Indian, Independence, Day, :, everything, ...
# 1102  (^, ", The, Philippines, ,, 1898â€“1946, |, US...
# 1132  (", Colonial, Cartographies, ,, Postcolonial, ...
# 1168  (The, Moldovans, :, Romania, ,, Russia, ,, and...
# 1232  (", Selling, ", Operation, Passage, to, Freedo...
# 1263  (", Stuck, in, Endless, Preliminaries, :, Viet...
# 1526  (", Anti, -, American, Behavior, in, the, Midd...
# 1532  (The, Rise, of, China, and, India, :, A, New, ...
# 1533               (Singapore, :, World, Scientific, .)
#
#                                                entities       country_name
# 1088                                            [India]            [India]
# 1093  [Indian Independence Day, Partition between In...         [Pakistan]
# 1102  [Philippines, 1898â€“1946, US House of Represe...      [Philippines]
# 1132  [Colonial Cartographies, Postcolonial Borders,...      [Afghanistan]
# 1168  [Moldovans, Romania, Russia, the Politics of C...  [Romania, Russia]
# 1232  [Thomas Dooley, the Religious Overtones of Ear...          [Vietnam]
# 1263  [Stuck in Endless Preliminaries, Vietnam, the ...          [Vietnam]
# 1526  [Anti-American Behavior, the Middle East, a Fi...          [Lebanon]
# 1532                                 [India, New Asian]            [India]
# 1533                      [Singapore, World Scientific]        [Singapore]

# %%
df_sentences_filtered['country_name'] = df_sentences_filtered['country_name'].apply(lambda x: [item.split()[0]
                                                                                                    for item in x])
# Out:
# C:\Users\justi\AppData\Local\Temp\ipykernel_18152\2662683012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sentences_filtered['country_name'] = df_sentences_filtered['country_name'].apply(lambda x: [item.split()[0]

# %%
df_sentences_filtered.tail(10)
# Out:
#                                                sentence  \
# 1088  (", The, forgotten, violence, that, helped, In...
# 1093  (", Indian, Independence, Day, :, everything, ...
# 1102  (^, ", The, Philippines, ,, 1898â€“1946, |, US...
# 1132  (", Colonial, Cartographies, ,, Postcolonial, ...
# 1168  (The, Moldovans, :, Romania, ,, Russia, ,, and...
# 1232  (", Selling, ", Operation, Passage, to, Freedo...
# 1263  (", Stuck, in, Endless, Preliminaries, :, Viet...
# 1526  (", Anti, -, American, Behavior, in, the, Midd...
# 1532  (The, Rise, of, China, and, India, :, A, New, ...
# 1533               (Singapore, :, World, Scientific, .)
#
#                                                entities       country_name
# 1088                                            [India]            [India]
# 1093  [Indian Independence Day, Partition between In...         [Pakistan]
# 1102  [Philippines, 1898â€“1946, US House of Represe...      [Philippines]
# 1132  [Colonial Cartographies, Postcolonial Borders,...      [Afghanistan]
# 1168  [Moldovans, Romania, Russia, the Politics of C...  [Romania, Russia]
# 1232  [Thomas Dooley, the Religious Overtones of Ear...          [Vietnam]
# 1263  [Stuck in Endless Preliminaries, Vietnam, the ...          [Vietnam]
# 1526  [Anti-American Behavior, the Middle East, a Fi...          [Lebanon]
# 1532                                 [India, New Asian]            [India]
# 1533                      [Singapore, World Scientific]        [Singapore]

# %%
# Defining relationships

# window size = 5 : this defines how many sentences will be looked at simultaneously
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i+5, df_sentences_filtered.index[-1])
    country_name = sum((df_sentences_filtered.loc[i: end_i].country_name), [])

     # Remove duplicated characters that are next to each other
    country_unique = [country_name[i] for i in range(len(country_name))
                             if (i==0) or country_name[i] != country_name[i-1]]

    if len(country_unique) > 1:
        for idx, a in enumerate( country_unique[ :-1]):
          b = country_unique[idx + 1]
          relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#       source     target
# 0     France     Russia
# 1     France     Russia
# 2     Russia    Germany
# 3    Germany    Austria
# 4    Austria    Hungary
# ..       ...        ...
# 591    India  Singapore
# 592    India  Singapore
# 593    India  Singapore
# 594    India  Singapore
# 595    India  Singapore
#
# [596 rows x 2 columns]

# %%
# Sort the cases with a- >b and b- >a
relationships_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationships_df.head(5)
# Out:
#     source   target
# 0   France   Russia
# 1   France   Russia
# 2  Germany   Russia
# 3  Austria  Germany
# 4  Austria  Hungary

# %%
relationships_df["value"] = 1
relationships_df = relationships_df.groupby(["source","target"], sort=False, as_index=False).sum()

relationships_df.head(10)
# Out:
#      source   target  value
# 0    France   Russia     12
# 1   Germany   Russia     26
# 2   Austria  Germany     17
# 3   Austria  Hungary      6
# 4  Bulgaria  Hungary      6
# 5  Bulgaria   Russia      6
# 6   Germany    Italy     25
# 7   Germany    Spain      2
# 8    France   Poland     14
# 9    France  Germany     24
